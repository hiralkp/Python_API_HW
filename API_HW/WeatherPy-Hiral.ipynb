# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import openweathermapy.core as owm
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint


# Import API key

from config import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

#URL for openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'

# api_key = "b811f7cbafe45cdaad2b27b74115d85f"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# lat_lngs = []
# cities = []

# # Create a set of random lat and lng combinations
# lats = np.random.uniform(low=-90.000, high=90.000, size=15)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=15)
# lat_lngs = zip(lats, lngs)
# lat_lngs

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['mataura',
#  'hobart',
#  'rosarito',
#  'ushuaia',
#  'bom jesus',
#  'dudinka',
#  'jamestown',
#  'albany',
#  'hilo',
#  'washougal',
#  'ribeira grande',
#  'savonlinna',
#  'the valley',
#  'bengkulu',
#  'codrington',
#  'bethel',
#  'punta arenas',
#  'cabo san lucas',
#  'eureka',
#  'vardo',
#  'yellowknife',
#  'khorixas',
#  'guerrero negro',
#  'naze',
#  'diphu',
#  'hervey bay',
#  'longyearbyen',
#  'pahrump',
#  'tessalit',
#  'roma',
#  'saint-philippe',
#  'cape town',
#  'sentyabrskiy',
#  'san cristobal',
#  'witu',
#  'adrar',
#  'riyadh',
#  'viedma',
#  'avarua',
#  'puerto ayora',
#  'freeport',
#  'port alfred',
#  'menongue',
#  'busselton',
#  'baoma',
#  'rikitea',
#  'sturgeon bay',
#  'kahului',
#  'taolanaro',
#  'macapa',
#  'lavrentiya',
#  'nanning',
#  'labuhan',
#  'ingham',
#  'cockburn town',
#  'samusu',
#  'miragoane',
#  'salalah',
#  'naryan-mar',
#  'miri',
#  'port elizabeth',
#  'guatire',
#  'vaini',
#  'coihaique',
#  'padang',
#  'san carlos de bariloche',
#  'pingyin',
#  'imbituba',
#  'inhambane',
#  'davenda',
#  'lorengau',
#  'nosy varika',
#  'qaanaaq',
#  'mareeba',
#  'inta',
#  'kruisfontein',
#  'macau',
#  'kondopoga',
#  'sinjar',
#  'ozinki',
#  'privokzalnyy',
#  'ampanihy',
#  'lebu',
#  'port shepstone',
#  'victoria',
#  'new norfolk',
#  'coquimbo',
#  'ostrovnoy',
#  'huarmey',
#  'cidreira',
#  'upernavik',
#  'miranorte',
#  'hithadhoo',
#  'sao filipe',
#  'college',
#  'belaya gora',
#  'baruun-urt',
#  'hermanus',
#  'tsihombe',
#  'severo-kurilsk',
#  'odda',
#  'port augusta',
#  'sibolga',
#  'sambava',
#  'clyde river',
#  'berlevag',
#  'nizhneyansk',
#  'nyandoma',
#  'thompson',
#  'yunhe',
#  'chifeng',
#  'fortuna',
#  'sunrise manor',
#  'sehithwa',
#  'mecca',
#  'el retorno',
#  'muros',
#  'nikolskoye',
#  'katsuura',
#  'kapaa',
#  'sungairaya',
#  'alice',
#  'tabiauea',
#  'tiksi',
#  'kamenskoye',
#  'kenora',
#  'caucasia',
#  'hasaki',
#  'zyryanskoye',
#  'chumikan',
#  'umzimvubu',
#  'arraial do cabo',
#  'sembe',
#  'malwan',
#  'chuy',
#  'kaitangata',
#  'narsaq',
#  'bonoua',
#  'souillac',
#  'camopi',
#  'ilulissat',
#  'palmer',
#  'bandarbeyla',
#  'iqaluit',
#  'bjornevatn',
#  'acarau',
#  'port blair',
#  'barentsburg',
#  'leningradskiy',
#  'cururupu',
#  'tilichiki',
#  'pochutla',
#  'lapi',
#  'illoqqortoormiut',
#  'tasiilaq',
#  'dalbandin',
#  'castro',
#  'bluff',
#  'ouesso',
#  'port-cartier',
#  'najran',
#  'kavieng',
#  'bredasdorp',
#  'kimbe',
#  'zlobin',
#  'barkhan',
#  'khatanga',
#  'biak',
#  'aguimes',
#  'nyurba',
#  'koungou',
#  'tuktoyaktuk',
#  'sao felix do xingu',
#  'caravelas',
#  'key west',
#  'bonfim',
#  'belushya guba',
#  'port moresby',
#  'seminole',
#  'laguna',
#  'booue',
#  'atasu',
#  'tuy hoa',
#  'bangassou',
#  'agadir',
#  'marsa matruh',
#  'alice springs',
#  'shenjiamen',
#  'ketchikan',
#  'tchibanga',
#  'shchelyayur',
#  'auxerre',
#  'provideniya',
#  'srednekolymsk',
#  'geraldton',
#  'port hardy',
#  'lubumbashi',
#  'ixtapa',
#  'saldanha',
#  'hualmay',
#  'faanui',
#  'tabuk',
#  'salavat',
#  'nha trang',
#  'lompoc',
#  'lethem',
#  'toliary',
#  'santo tomas',
#  'oktyabrskiy',
#  'sitka',
#  'sonamura',
#  'kodiak',
#  'zhashkiv',
#  'russell',
#  'deqing',
#  'chokurdakh',
#  'slave lake',
#  'wadi musa',
#  'port lincoln',
#  'talnakh',
#  'makokou',
#  'guadalupe',
#  'los llanos de aridane',
#  'dicabisagan',
#  'mandalay',
#  'halalo',
#  'ust-tsilma',
#  'ancud',
#  'jiayuguan',
#  'butaritari',
#  'manzil tamim',
#  'margate',
#  'okhotsk',
#  'feldkirchen an der donau',
#  'kiunga',
#  'bambous virieux',
#  'qianjiang',
#  'sur',
#  'antalaha',
#  'meulaboh',
#  'hun',
#  'noumea',
#  'kaeo',
#  'san patricio',
#  'asau',
#  'bilma',
#  'ola',
#  'palabuhanratu',
#  'bomet',
#  'sumbawa',
#  'inverell',
#  'attawapiskat',
#  'villazon',
#  'dikson',
#  'mar del plata',
#  'brooks',
#  'saint anthony',
#  'pevek',
#  'tura',
#  'te anau',
#  'saint george',
#  'torbay',
#  'birobidzhan',
#  'norman wells',
#  'yerbogachen',
#  'dornoch',
#  'bozova',
#  'namibe',
#  'marcona',
#  'nanortalik',
#  'saint-pierre',
#  'krzeszowice',
#  'turtas',
#  'honiara',
#  'nakusp',
#  'amderma',
#  'talavera de la reina',
#  'erzin',
#  'tlahualilo',
#  'harper',
#  'lolua',
#  'smithers',
#  'camana',
#  'mocambique',
#  'barrow',
#  'mys shmidta',
#  'anloga',
#  'safford',
#  'crangeni',
#  'jalu',
#  'alibag',
#  'phan thiet',
#  'adre',
#  'yulara',
#  'east london',
#  'vanino',
#  'nouadhibou',
#  'pucallpa',
#  'charagua',
#  'saskylakh']

# %%
len(cities)
# Out:
# 300

# %%
# query_url = url + "&appid=" + api_key +"&units=" + units + "&q="
# # query_url = url + "&appid=" + api_key +"&units=" + units
# query_url
# # weather_response = requests.get(query_url).json()

# %%
# weather_response = requests.get(query_url).json()
# weather_response

# %%
temp = []
#cities = ["bluff", "vagur"]
lat =[]
lon =[]
sunrise = []
sunset = []
name = []
i=0
for city in cities:
    i=i+1
    #print("-------------------------------------------------------------------------------------------------------------------")
    print(city,i)
    query_url = url + "&appid=" + api_key +"&units=" + units + "&q=" + city
   #print(query_url)
    #print("-------------------------------------------------------------------------------------------------------------------")
    response = requests.get(query_url).json()
   # print(response)
    #if response['cod'] != '404':
    try:    
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        sunrise.append(response['sys']['sunrise'])
        sunset.append(response['sys']['sunset'])
        name.append(response['name'])
        
    #print(f"The latitude information received is: {lat}")
    #print(f"The temperature information received is: {temp}")
    #else:
    except:
            print("city not found")
#print("-------------------------------------------------------------------------------------------------------------------")
#print("response:")     
#print("-------------------------------------------------------------------------------------------------------------------")
print("Temp: " + str(temp))
print("Lat: " + str(lat))
print("Lon: " + str(lon))
# print("Sunrise: " + str(sunrise))
# print("Sunset: " + str(sunset))
#print("City name: " + str(name))
# Out:
# mataura 1
# hobart 2
# rosarito 3
# ushuaia 4
# bom jesus 5
# dudinka 6
# jamestown 7
# albany 8
# hilo 9
# washougal 10
# ribeira grande 11
# savonlinna 12
# the valley 13
# bengkulu 14
# city not found
# codrington 15
# bethel 16
# punta arenas 17
# cabo san lucas 18
# eureka 19
# vardo 20
# yellowknife 21
# khorixas 22
# guerrero negro 23
# naze 24
# diphu 25
# hervey bay 26
# longyearbyen 27
# pahrump 28
# tessalit 29
# roma 30
# saint-philippe 31
# cape town 32
# sentyabrskiy 33
# city not found
# san cristobal 34
# witu 35
# adrar 36
# riyadh 37
# viedma 38
# avarua 39
# puerto ayora 40
# freeport 41
# port alfred 42
# menongue 43
# busselton 44
# baoma 45
# rikitea 46
# sturgeon bay 47
# kahului 48
# taolanaro 49
# city not found
# macapa 50
# lavrentiya 51
# nanning 52
# labuhan 53
# ingham 54
# cockburn town 55
# samusu 56
# city not found
# miragoane 57
# salalah 58
# naryan-mar 59
# miri 60
# port elizabeth 61
# guatire 62
# vaini 63
# coihaique 64
# padang 65
# san carlos de bariloche 66
# pingyin 67
# imbituba 68
# inhambane 69
# davenda 70
# lorengau 71
# nosy varika 72
# qaanaaq 73
# mareeba 74
# inta 75
# kruisfontein 76
# macau 77
# kondopoga 78
# sinjar 79
# ozinki 80
# privokzalnyy 81
# city not found
# ampanihy 82
# lebu 83
# port shepstone 84
# victoria 85
# new norfolk 86
# coquimbo 87
# ostrovnoy 88
# huarmey 89
# cidreira 90
# upernavik 91
# mar del plata 255
# brooks 256
# saint anthony 257
# pevek 258
# tura 259
# te anau 260
# saint george 261
# torbay 262
# birobidzhan 263
# norman wells 264
# yerbogachen 265
# dornoch 266
# bozova 267
# namibe 268
# marcona 269
# city not found
# nanortalik 270
# saint-pierre 271
# krzeszowice 272
# turtas 273
# honiara 274
# nakusp 275
# amderma 276
# city not found
# talavera de la reina 277
# erzin 278
# tlahualilo 279
# city not found
# harper 280
# lolua 281
# city not found
# smithers 282
# camana 283
# city not found
# mocambique 284
# city not found
# barrow 285
# mys shmidta 286
# city not found
# anloga 287
# safford 288
# crangeni 289
# jalu 290
# alibag 291
# phan thiet 292
# adre 293
# yulara 294
# east london 295
# vanino 296
# nouadhibou 297
# pucallpa 298
# charagua 299
# saskylakh 300
# Temp: [33.16, 53.6, 77.79, 36.41, 86, 34.96, 57.55, 60.1, 70.75, 63.99, 75.2, 33.8, 86.13, 46.39, 50, 41, 87.87, 65.21, 78.22, 26.6, 82.39, 72.22, 80.6, 69.07, 67.99, 30.2, 77.34, 88.96, 65.73, 50.29, 55.4, 69.8, 76.9, 91.4, 86, 56.83, 69.8, 77, 86, 61.24, 78.97, 55.66, 59.53, 68.62, 54.14, 75.31, 95, 45.58, 69.8, 69.43, 71.86, 82.93, 84.82, 78.8, 37.57, 72.94, 80.65, 87.8, 72.13, 50, 81.22, 46.4, 51.34, 69.8, 75.2, 32.35, 82.84, 67.72, 26.14, 68, 40.18, 60.34, 96.16, 44.6, 77, 43.87, 72.04, 56.83, 68.71, 77.79, 53.6, 64.4, 22.99, 72.13, 63.94, 34.96, 80.32, 79.33, 34.84, 27.13, 36.85, 51.7, 47.74, 28.84, 59, 68.44, 75.37, 23, 33.8, 46.03, 41, 45.4, 35.86, 72.99, 77.32, 75.37, 85.36, 88.96, 64.4, 44.6, 63.13, 78.98, 74.83, 89.02, 24.43, 48.31, 86.62, 63.55, 35.59, 45.31, 88.68, 59.17, 32.44, 39.2, 78.8, 59.97, 92.29, 32, 43.84, 77.17, 32, 33.44, 85.09, 41.17, 89.86, 40.81, 88.56, 44.6, 33.8, 61.78, 48.82, 57.73, 77.98, 42.8, 77, 83.83, 53.6, 77.17, 57.2, 53.86, 30.46, 76.36, 75.2, 38.02, 26.6, 87.43, 77.89, 56.73, 87.8, 77.26, 80.38, 87.8, 72.76, 36.49, 75.28, 76.36, 77, 78.8, 69.8, 71.77, 51.37, 74.65, 55.4, 47.47, 25.6, 53.6, 50, 67.36, 87.8, 65.74, 70.78, 75.64, 61.24, 40.45, 76.99, 70.3, 98.77, 68.71, 45.97, 84.46, 79.78, 80.06, 49.9, 68, 60.8, 30.91, 32, 76.36, 57.91, 33.79, 72.94, 78.62, 75.2, 73.66, 73.03, 41.44, 50.17, 27.85, 84.1, 53.6, 32.98, 50, 72.49, 71.6, 55.93, 82.84, 71.5, 78.79, 56.86, 62.6, 45.67, 67.81, 93.73,